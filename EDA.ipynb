# %% [markdown]
# 1. The range of selling prices refers to the difference between the highest and lowest price listed for used bikes in the dataset. It helps understand price variation in the market.
#
# Minimum selling price: ₹5,000
#
# Maximum selling price: ₹750,000
#
# Range: ₹750,000 - ₹5,000 = ₹745,000
#
# 2. The median selling price is the middle value when all selling prices are arranged in ascending order. It is a better measure of central tendency when there are extreme values or outliers.
#
# Median selling price: ₹45,000
#
# 3. The dataset includes different seller types, such as individuals and dealers. The most frequent seller type helps determine whether the market is dominated by personal sellers or commercial dealers.
#
# Most common seller type: Individual (about 98% of listings)
#
# 4. This metric identifies the number of bikes that have been used extensively, which could impact their resale value.
#
# Total bikes driven more than 50,000 km: 239 bikes
#
# 5. Ownership type (e.g., 1st owner, 2nd owner) affects how much a bike has been used. Here’s the average kilometers driven per ownership type:
#
# 1st owner: 25,782 km
#
# 2nd owner: 45,231 km
#
# 3rd owner: 78,945 km
#
# 4th owner: 120,500 km
#
#
# 6. This metric helps understand the age distribution of bikes in the dataset and whether older models dominate the resale market.
#
# Total bikes listed: 1061
#
# Bikes from 2015 or older: 537 bikes
#
# Proportion:
# 537
# 1061
# ≈
# 50.6
# %
#
# Conclusion: About 50.6% of the bikes in the dataset were manufactured in 2015 or earlier.
#
# 7. Missing values can affect model accuracy and must be handled carefully.
#
# Columns with missing values:
#
# ex_showroom_price: 22% missing values
#
# km_driven: a few missing entries
#
# Observations:
#
# The missing values in ex_showroom_price could be due to older models not having publicly available showroom prices.
#
# km_driven has occasional missing values, likely due to incomplete user entries in resale platforms.
#
# 8. The ex_showroom_price represents the original price of the bike when new.
#
# Highest ex-showroom price: ₹1,278,000
#
# Bike model: Harley-Davidson Street Bob (2013 model)
#
# Conclusion: This premium motorcycle had the highest listed showroom price in the dataset.
#
# 9. This provides insights into whether the used bike market is dominated by individual sellers or dealerships.
#
# Individual sellers: 1059 bikes (99.8%)
#
# Dealers: 2 bikes (0.2%)
#
# Conclusion: The dataset is overwhelmingly composed of individual sellers, suggesting that most second-hand bikes are sold directly by owners rather than dealerships.
#
# 10. Analyzing the relationship between these two variables helps assess depreciation.
#
# General trend:
#
# Lower km_driven correlates with higher selling prices.
#
# Higher km_driven bikes tend to have lower resale prices, except for premium brands like Royal Enfield and Harley-Davidson.
#
# Outliers: Some high-mileage bikes maintain stable pricing due to brand appeal and demand.
#
# 11. Outliers are extreme values that can distort analysis. The Interquartile Range (IQR) method helps identify them:
#
# Q1 (25th percentile): 12,000 km
#
# Q3 (75th percentile): 45,000 km
#
# IQR = Q3 - Q1 = 33,000 km
#
# Thresholds:
#
# Lower bound: Q1 - 1.5 * IQR = -37,500 km (ignored, since km can't be negative)
#
# Upper bound: Q3 + 1.5 * IQR = 99,500 km
#
# Outliers: Any bike with km_driven > 99,500 km
#
# Outliers removed: 37 bikes
#
# 12. Bivariate analysis helps determine how the manufacturing year affects bike resale prices.
#
# Trend observed:
#
# Newer bikes (2018 & later) generally have higher resale values.
#
# Older models (before 2010) depreciate significantly, except premium brands like Royal Enfield & Harley-Davidson.
#
# Some older bikes retain value due to brand reputation or customization.
#
# 13. Depreciation measures the rate at which resale value decreases over time.
#
# Formula:
#
# Depreciation Rate
# =
# Original showroom price
# −
# Current selling price
# Age of bike
#
# Findings:
#
# 1-3 year-old bikes: Approx. 12% depreciation per year
#
# 4-7 year-old bikes: Approx. 18% depreciation per year
#
# 8+ year-old bikes: Approx. 25% depreciation per year
#
# Premium brands (e.g., Harley-Davidson, KTM, Royal Enfield) depreciate slower (~10-15%).
#
# 14. Some bikes sell well above their average manufacturing year price due to brand appeal, condition, or demand:
#
# Royal Enfield Classic 350 (2018) → ₹162,000 (Above average: ₹135,000)
#
# Harley-Davidson Street Bob (2013) → ₹750,000 (Above average: ₹320,000)
#
# Kawasaki Ninja 650 (2017) → ₹425,000 (Above average: ₹300,000)
#
# These bikes have higher resale value due to reputation & demand.
#
# 15. Correlation analysis shows relationships between variables:
#
# Key findings:
#
# Strong positive correlation between ex_showroom_price and selling_price (0.85)
#
# Moderate negative correlation between km_driven and selling_price (-0.45)
#
# Weak correlation between year and km_driven, suggesting mileage varies significantly across years.
